# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 1. Reading data set to python environment

# %%
iris_data = pd.read_excel(r'C:\Users\user\Desktop\iris.xls')
iris_data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # 2.Display the columns in the dataset

# %%
iris_data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # 3.Calculate the mean of each column of the dataset

# %%
iris_data.mean(axis=0,numeric_only=True)#calculated the mean of numeric values column wise,without ,numeric_only=True shows future error
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4.Check for the null values present in the data set

# %%
iris_data.isna().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %%
#no null values present in the data set

# %% [markdown]
# # 5.Perform meaningful visualisation using the data set.Bring at least three visualisation

# %%
iris_data1=iris_data[['SL','SW','PL','PW']]
sns.heatmap(iris_data1.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.bar(iris_data['Classification'],iris_data['SL'])
plt.show()

# %%
plt.bar(iris_data['Classification'],iris_data['PL'])
plt.show()

# %%
plt.bar(iris_data['Classification'],iris_data['SW'])
plt.show()

# %%
plt.bar(iris_data['Classification'],iris_data['PW'])
plt.show()

# %%
sns.countplot(x='PW',data=iris_data,hue='Classification')
# Out:
# <Axes: xlabel='PW', ylabel='count'>

# %%
sns.countplot(x='SW',data=iris_data,hue='Classification')
# Out:
# <Axes: xlabel='SW', ylabel='count'>

# %%
sns.boxplot(x='SW',y='PW',data=iris_data)
# Out:
# <Axes: xlabel='SW', ylabel='PW'>
